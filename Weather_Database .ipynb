# %%
#Create a new set of 2,000 random latitudes and longitudes.
import random 
import numpy as np 
import pandas as pd 
import requests
import time
# Import the API key.
from config import weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 778

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1a807b332de63556c8bcc803af1bca6d

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(30)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
        # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            weather_description = city_weather["weather"][0]["description"]
 
        # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
            print("City not found. Skipping...")
            pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | fuling
# Processing Record 2 of Set 1 | upernavik
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | fortuna
# Processing Record 6 of Set 1 | kruisfontein
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | ribeira grande
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | provideniya
# Processing Record 12 of Set 1 | monte alegre
# Processing Record 13 of Set 1 | pishin
# Processing Record 14 of Set 1 | bathsheba
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | balkanabat
# Processing Record 18 of Set 1 | uribia
# Processing Record 19 of Set 1 | biltine
# Processing Record 20 of Set 1 | labuhan
# Processing Record 21 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 1 | soyo
# Processing Record 23 of Set 1 | chokurdakh
# Processing Record 24 of Set 1 | kirensk
# Processing Record 25 of Set 1 | alofi
# Processing Record 26 of Set 1 | palencia
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | kavieng
# Processing Record 29 of Set 1 | olafsvik
# Processing Record 30 of Set 1 | severo-kurilsk
# Processing Record 31 of Set 1 | shimoda
# Processing Record 32 of Set 1 | sayat
# Processing Record 33 of Set 1 | pontianak
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | fallon
# Processing Record 37 of Set 1 | pochutla
# Processing Record 38 of Set 1 | vyartsilya
# Processing Record 39 of Set 1 | comarapa
# Processing Record 40 of Set 1 | port elizabeth
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | chuy
# Processing Record 44 of Set 1 | coos bay
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | ancud
# Processing Record 47 of Set 1 | acapulco
# Processing Record 48 of Set 1 | kuito
# Processing Record 49 of Set 1 | myanaung
# Processing Record 50 of Set 1 | praia da vitoria
# Processing Record 1 of Set 2 | pangnirtung
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | njombe
# Processing Record 4 of Set 2 | leningradskiy
# Processing Record 5 of Set 2 | husavik
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | havre-saint-pierre
# Processing Record 8 of Set 2 | mutare
# Processing Record 9 of Set 2 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 10 of Set 2 | narsaq
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | kaitangata
# Processing Record 13 of Set 2 | eureka
# Processing Record 14 of Set 2 | torbay
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | altay
# Processing Record 17 of Set 2 | vicuna
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | marang
# Processing Record 20 of Set 2 | zlatoustovsk
# City not found. Skipping...
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | pevek
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | barrow
# Processing Record 25 of Set 2 | fort-shevchenko
# Processing Record 26 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 2 | hasaki
# Processing Record 28 of Set 2 | caldas novas
# Processing Record 29 of Set 2 | lebu
# Processing Record 30 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 2 | nha trang
# Processing Record 32 of Set 2 | pila
# Processing Record 33 of Set 2 | norman wells
# Processing Record 34 of Set 2 | solsvik
# City not found. Skipping...
# Processing Record 35 of Set 2 | dingle
# Processing Record 36 of Set 2 | avarua
# Processing Record 37 of Set 2 | grindavik
# Processing Record 38 of Set 2 | ostrovnoy
# Processing Record 39 of Set 2 | sioux lookout
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | hurghada
# Processing Record 42 of Set 2 | cidreira
# Processing Record 43 of Set 2 | innisfail
# Processing Record 44 of Set 2 | tilichiki
# Processing Record 45 of Set 2 | tuggurt
# City not found. Skipping...
# Processing Record 46 of Set 2 | millinocket
# Processing Record 47 of Set 2 | carnarvon
# Processing Record 48 of Set 2 | oranjemund
# Processing Record 49 of Set 2 | vaini
# Processing Record 50 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Record 2 of Set 3 | bajos de haina
# Processing Record 3 of Set 3 | boda
# Processing Record 4 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 3 | ellisras
# Processing Record 6 of Set 3 | bosaso
# Processing Record 7 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 8 of Set 3 | along
# Processing Record 9 of Set 3 | morant bay
# Processing Record 10 of Set 3 | tiksi
# Processing Record 11 of Set 3 | medina
# Processing Record 12 of Set 3 | abeche
# Processing Record 13 of Set 3 | baruun-urt
# Processing Record 14 of Set 3 | saldanha
# Processing Record 15 of Set 3 | chapais
# Processing Record 16 of Set 3 | caarapo
# Processing Record 17 of Set 3 | linqiong
# Processing Record 18 of Set 3 | faanui
# Processing Record 19 of Set 3 | sitka
# Processing Record 20 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 3 | sindor
# Processing Record 22 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | kahului
# Processing Record 25 of Set 3 | nanortalik
# Processing Record 26 of Set 3 | acarau
# Processing Record 27 of Set 3 | urumqi
# Processing Record 28 of Set 3 | hithadhoo
# Processing Record 29 of Set 3 | lata
# Processing Record 30 of Set 3 | saint-pierre
# Processing Record 31 of Set 3 | kisangani
# Processing Record 32 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 3 | raton
# Processing Record 34 of Set 3 | hami
# Processing Record 35 of Set 3 | fountain
# Processing Record 36 of Set 3 | sao joao da barra
# Processing Record 37 of Set 3 | nuuk
# Processing Record 38 of Set 3 | hilo
# Processing Record 39 of Set 3 | katangli
# Processing Record 40 of Set 3 | cabo san lucas
# Processing Record 41 of Set 3 | gat
# Processing Record 42 of Set 3 | dandong
# Processing Record 43 of Set 3 | estrela
# Processing Record 44 of Set 3 | male
# Processing Record 45 of Set 3 | zhezkazgan
# Processing Record 46 of Set 3 | thompson
# Processing Record 47 of Set 3 | mityana
# Processing Record 48 of Set 3 | nalut
# Processing Record 49 of Set 3 | asyut
# Processing Record 50 of Set 3 | leghorn
# City not found. Skipping...
# Processing Record 1 of Set 4 | hobart
# Processing Record 2 of Set 4 | jamestown
# Processing Record 3 of Set 4 | agadir
# Processing Record 4 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 5 of Set 4 | esperance
# Processing Record 6 of Set 4 | tomatlan
# Processing Record 7 of Set 4 | mar del plata
# Processing Record 8 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 4 | nouakchott
# Processing Record 10 of Set 4 | bouar
# Processing Record 11 of Set 4 | isangel
# Processing Record 12 of Set 4 | najran
# Processing Record 13 of Set 4 | tosya
# Processing Record 14 of Set 4 | vao
# Processing Record 15 of Set 4 | dunedin
# Processing Record 16 of Set 4 | hampton
# Processing Record 17 of Set 4 | siuna
# Processing Record 18 of Set 4 | la rochelle
# Processing Record 19 of Set 4 | ludza
# Processing Record 20 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 4 | meulaboh
# Processing Record 22 of Set 4 | half moon bay
# Processing Record 23 of Set 4 | airai
# Processing Record 24 of Set 4 | tocopilla
# Processing Record 25 of Set 4 | bredasdorp
# Processing Record 26 of Set 4 | malpe
# Processing Record 27 of Set 4 | hovd
# Processing Record 28 of Set 4 | lakes entrance
# Processing Record 29 of Set 4 | georgetown
# Processing Record 30 of Set 4 | comodoro rivadavia
# Processing Record 31 of Set 4 | nichinan
# Processing Record 32 of Set 4 | weiser
# Processing Record 33 of Set 4 | longyearbyen
# Processing Record 34 of Set 4 | matipo
# Processing Record 35 of Set 4 | trinidad
# Processing Record 36 of Set 4 | deputatskiy
# Processing Record 37 of Set 4 | alice town
# Processing Record 38 of Set 4 | victoria
# Processing Record 39 of Set 4 | warrington
# Processing Record 40 of Set 4 | touros
# Processing Record 41 of Set 4 | saint-philippe
# Processing Record 42 of Set 4 | abastumani
# Processing Record 43 of Set 4 | adrar
# Processing Record 44 of Set 4 | velyka pysarivka
# Processing Record 45 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 4 | anadyr
# Processing Record 47 of Set 4 | kindu
# Processing Record 48 of Set 4 | kimbe
# Processing Record 49 of Set 4 | alanya
# Processing Record 50 of Set 4 | komsomolskiy
# Processing Record 1 of Set 5 | aklavik
# Processing Record 2 of Set 5 | ada
# Processing Record 3 of Set 5 | grand gaube
# Processing Record 4 of Set 5 | boca do acre
# Processing Record 5 of Set 5 | kelvington
# Processing Record 6 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 7 of Set 5 | neuquen
# Processing Record 8 of Set 5 | souillac
# Processing Record 9 of Set 5 | klaksvik
# Processing Record 10 of Set 5 | tasiilaq
# Processing Record 11 of Set 5 | antigonish
# Processing Record 12 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 5 | talnakh
# Processing Record 15 of Set 5 | nisia floresta
# Processing Record 16 of Set 5 | bogorodskoye
# Processing Record 17 of Set 5 | saskylakh
# Processing Record 18 of Set 5 | segovia
# Processing Record 19 of Set 5 | kieta
# Processing Record 20 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 5 | berlevag
# Processing Record 22 of Set 5 | moerai
# Processing Record 23 of Set 5 | morros
# Processing Record 24 of Set 5 | plavinas
# Processing Record 25 of Set 5 | nortelandia
# Processing Record 26 of Set 5 | miranda
# Processing Record 27 of Set 5 | stornoway
# Processing Record 28 of Set 5 | anito
# Processing Record 29 of Set 5 | humboldt
# Processing Record 30 of Set 5 | rudbar
# Processing Record 31 of Set 5 | kiruna
# Processing Record 32 of Set 5 | olinda
# Processing Record 33 of Set 5 | camargo
# Processing Record 34 of Set 5 | mount gambier
# Processing Record 35 of Set 5 | lavrentiya
# Processing Record 36 of Set 5 | ponta do sol
# Processing Record 37 of Set 5 | daru
# Processing Record 38 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 5 | mandla
# Processing Record 40 of Set 5 | talaya
# Processing Record 41 of Set 5 | kalmar
# Processing Record 42 of Set 5 | talara
# Processing Record 43 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 44 of Set 5 | pundaguitan
# Processing Record 45 of Set 5 | stephenville
# Processing Record 46 of Set 5 | east london
# Processing Record 47 of Set 5 | beberibe
# Processing Record 48 of Set 5 | aripuana
# Processing Record 49 of Set 5 | bethel
# Processing Record 50 of Set 5 | bilibino
# Processing Record 1 of Set 6 | bambous virieux
# Processing Record 2 of Set 6 | banjar
# Processing Record 3 of Set 6 | nizwa
# Processing Record 4 of Set 6 | flin flon
# Processing Record 5 of Set 6 | ilulissat
# Processing Record 6 of Set 6 | fertod
# Processing Record 7 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 6 | kichera
# Processing Record 9 of Set 6 | pacific grove
# Processing Record 10 of Set 6 | iqaluit
# Processing Record 11 of Set 6 | palora
# Processing Record 12 of Set 6 | tura
# Processing Record 13 of Set 6 | vuktyl
# Processing Record 14 of Set 6 | castro
# Processing Record 15 of Set 6 | biak
# Processing Record 16 of Set 6 | san cristobal
# Processing Record 17 of Set 6 | saint george
# Processing Record 18 of Set 6 | cozumel
# Processing Record 19 of Set 6 | severodvinsk
# Processing Record 20 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 6 | zhangye
# Processing Record 22 of Set 6 | bonfim
# Processing Record 23 of Set 6 | jizan
# Processing Record 24 of Set 6 | dzhida
# Processing Record 25 of Set 6 | kharopon
# Processing Record 26 of Set 6 | linchuan
# City not found. Skipping...
# Processing Record 27 of Set 6 | atambua
# Processing Record 28 of Set 6 | khani
# Processing Record 29 of Set 6 | quatre cocos
# Processing Record 30 of Set 6 | ixtapa
# Processing Record 31 of Set 6 | kannad
# Processing Record 32 of Set 6 | monte santo de minas
# Processing Record 33 of Set 6 | oytal
# Processing Record 34 of Set 6 | namatanai
# Processing Record 35 of Set 6 | yumen
# Processing Record 36 of Set 6 | cayenne
# Processing Record 37 of Set 6 | sokolskoye
# Processing Record 38 of Set 6 | perene
# Processing Record 39 of Set 6 | lagoa
# Processing Record 40 of Set 6 | tyrma
# Processing Record 41 of Set 6 | nizhniy bestyakh
# Processing Record 42 of Set 6 | baijiantan
# Processing Record 43 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 6 | geraldton
# Processing Record 45 of Set 6 | kloulklubed
# Processing Record 46 of Set 6 | beringovskiy
# Processing Record 47 of Set 6 | nioki
# Processing Record 48 of Set 6 | emba
# Processing Record 49 of Set 6 | ferrol
# Processing Record 50 of Set 6 | marsa matruh
# Processing Record 1 of Set 7 | leh
# Processing Record 2 of Set 7 | ximei
# Processing Record 3 of Set 7 | tevaitoa
# Processing Record 4 of Set 7 | muros
# Processing Record 5 of Set 7 | sambava
# Processing Record 6 of Set 7 | pacifica
# Processing Record 7 of Set 7 | kambove
# Processing Record 8 of Set 7 | necochea
# Processing Record 9 of Set 7 | conselheiro lafaiete
# Processing Record 10 of Set 7 | itamaraca
# Processing Record 11 of Set 7 | kampot
# Processing Record 12 of Set 7 | hervey bay
# Processing Record 13 of Set 7 | mao
# Processing Record 14 of Set 7 | codrington
# Processing Record 15 of Set 7 | vila velha
# Processing Record 16 of Set 7 | laguna
# Processing Record 17 of Set 7 | bonavista
# Processing Record 18 of Set 7 | pingdu
# Processing Record 19 of Set 7 | nikolskoye
# Processing Record 20 of Set 7 | tecoanapa
# Processing Record 21 of Set 7 | warri
# Processing Record 22 of Set 7 | huaiyin
# Processing Record 23 of Set 7 | faya
# Processing Record 24 of Set 7 | sabha
# Processing Record 25 of Set 7 | bowen
# Processing Record 26 of Set 7 | joshimath
# Processing Record 27 of Set 7 | cap malheureux
# Processing Record 28 of Set 7 | ardakan
# Processing Record 29 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 30 of Set 7 | cedar rapids
# Processing Record 31 of Set 7 | kyshtovka
# Processing Record 32 of Set 7 | kununurra
# Processing Record 33 of Set 7 | hamilton
# Processing Record 34 of Set 7 | urambo
# Processing Record 35 of Set 7 | man
# Processing Record 36 of Set 7 | kamina
# Processing Record 37 of Set 7 | buchanan
# Processing Record 38 of Set 7 | mataram
# Processing Record 39 of Set 7 | tabat
# Processing Record 40 of Set 7 | dudinka
# Processing Record 41 of Set 7 | mahebourg
# Processing Record 42 of Set 7 | san vicente
# Processing Record 43 of Set 7 | sakaiminato
# Processing Record 44 of Set 7 | jingdezhen
# Processing Record 45 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 7 | bijie
# Processing Record 47 of Set 7 | kharian
# Processing Record 48 of Set 7 | ketchikan
# Processing Record 49 of Set 7 | yerbogachen
# Processing Record 50 of Set 7 | san rafael del sur
# Processing Record 1 of Set 8 | broome
# Processing Record 2 of Set 8 | sorland
# Processing Record 3 of Set 8 | port-cartier
# Processing Record 4 of Set 8 | svetlogorsk
# Processing Record 5 of Set 8 | havelock
# Processing Record 6 of Set 8 | tual
# Processing Record 7 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 8 | katsuura
# Processing Record 9 of Set 8 | shaunavon
# Processing Record 10 of Set 8 | zwiesel
# Processing Record 11 of Set 8 | caravelas
# Processing Record 12 of Set 8 | gunjur
# Processing Record 13 of Set 8 | marsh harbour
# Processing Record 14 of Set 8 | luderitz
# Processing Record 15 of Set 8 | varska
# City not found. Skipping...
# Processing Record 16 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 8 | stettler
# Processing Record 18 of Set 8 | esil
# Processing Record 19 of Set 8 | waipawa
# Processing Record 20 of Set 8 | srednekolymsk
# Processing Record 21 of Set 8 | vlore
# Processing Record 22 of Set 8 | arraial do cabo
# Processing Record 23 of Set 8 | mogadishu
# Processing Record 24 of Set 8 | antalaha
# Processing Record 25 of Set 8 | lethem
# Processing Record 26 of Set 8 | spring valley
# Processing Record 27 of Set 8 | polyarnyye zori
# Processing Record 28 of Set 8 | sosua
# Processing Record 29 of Set 8 | carrickfergus
# Processing Record 30 of Set 8 | padang
# Processing Record 31 of Set 8 | saint-ambroise
# Processing Record 32 of Set 8 | olbia
# Processing Record 33 of Set 8 | puerto quijarro
# Processing Record 34 of Set 8 | puerto vallarta
# Processing Record 35 of Set 8 | tumaco
# Processing Record 36 of Set 8 | maridi
# Processing Record 37 of Set 8 | kushmurun
# Processing Record 38 of Set 8 | pisco
# Processing Record 39 of Set 8 | khonsar
# City not found. Skipping...
# Processing Record 40 of Set 8 | ranong
# Processing Record 41 of Set 8 | biratnagar
# Processing Record 42 of Set 8 | saint-augustin
# Processing Record 43 of Set 8 | novonukutskiy
# Processing Record 44 of Set 8 | riohacha
# Processing Record 45 of Set 8 | zholymbet
# Processing Record 46 of Set 8 | sehithwa
# Processing Record 47 of Set 8 | sao filipe
# Processing Record 48 of Set 8 | araouane
# Processing Record 49 of Set 8 | salinas
# Processing Record 50 of Set 8 | tautira
# Processing Record 1 of Set 9 | san andres
# Processing Record 2 of Set 9 | raudeberg
# Processing Record 3 of Set 9 | luang prabang
# Processing Record 4 of Set 9 | teguise
# Processing Record 5 of Set 9 | schwedt
# Processing Record 6 of Set 9 | wakiso
# Processing Record 7 of Set 9 | turinsk
# Processing Record 8 of Set 9 | samarai
# Processing Record 9 of Set 9 | itarema
# Processing Record 10 of Set 9 | jalu
# Processing Record 11 of Set 9 | narok
# Processing Record 12 of Set 9 | molteno
# Processing Record 13 of Set 9 | jumla
# Processing Record 14 of Set 9 | towada
# Processing Record 15 of Set 9 | sawakin
# Processing Record 16 of Set 9 | los chiles
# Processing Record 17 of Set 9 | olga
# Processing Record 18 of Set 9 | gasa
# Processing Record 19 of Set 9 | kudahuvadhoo
# Processing Record 20 of Set 9 | derbent
# Processing Record 21 of Set 9 | namibe
# Processing Record 22 of Set 9 | banda aceh
# Processing Record 23 of Set 9 | freeport
# Processing Record 24 of Set 9 | vitim
# Processing Record 25 of Set 9 | natal
# Processing Record 26 of Set 9 | lompoc
# Processing Record 27 of Set 9 | nome
# Processing Record 28 of Set 9 | port hedland
# Processing Record 29 of Set 9 | kofarnihon
# City not found. Skipping...
# Processing Record 30 of Set 9 | lorengau
# Processing Record 31 of Set 9 | wanning
# Processing Record 32 of Set 9 | harnosand
# Processing Record 33 of Set 9 | ongandjera
# Processing Record 34 of Set 9 | sao miguel do araguaia
# Processing Record 35 of Set 9 | lithgow
# Processing Record 36 of Set 9 | kirakira
# Processing Record 37 of Set 9 | juneau
# Processing Record 38 of Set 9 | boyolangu
# Processing Record 39 of Set 9 | san quintin
# Processing Record 40 of Set 9 | port lincoln
# Processing Record 41 of Set 9 | mundargi
# Processing Record 42 of Set 9 | chiguiri arriba
# City not found. Skipping...
# Processing Record 43 of Set 9 | santa cruz de tenerife
# Processing Record 44 of Set 9 | kalemie
# Processing Record 45 of Set 9 | paamiut
# Processing Record 46 of Set 9 | yaring
# Processing Record 47 of Set 9 | lac-megantic
# Processing Record 48 of Set 9 | korla
# Processing Record 49 of Set 9 | mecca
# Processing Record 50 of Set 9 | mount isa
# Processing Record 1 of Set 10 | yarmouth
# Processing Record 2 of Set 10 | iguape
# Processing Record 3 of Set 10 | a
# City not found. Skipping...
# Processing Record 4 of Set 10 | ubinskoye
# Processing Record 5 of Set 10 | dhidhdhoo
# Processing Record 6 of Set 10 | toamasina
# Processing Record 7 of Set 10 | yar-sale
# Processing Record 8 of Set 10 | tabas
# Processing Record 9 of Set 10 | ruwi
# Processing Record 10 of Set 10 | sukhumi
# Processing Record 11 of Set 10 | iskateley
# Processing Record 12 of Set 10 | tougan
# Processing Record 13 of Set 10 | henties bay
# Processing Record 14 of Set 10 | yulara
# Processing Record 15 of Set 10 | nemuro
# Processing Record 16 of Set 10 | tazovskiy
# Processing Record 17 of Set 10 | ust-kuyga
# Processing Record 18 of Set 10 | cairns
# Processing Record 19 of Set 10 | hambantota
# Processing Record 20 of Set 10 | rockhampton
# Processing Record 21 of Set 10 | buala
# Processing Record 22 of Set 10 | dindori
# Processing Record 23 of Set 10 | nyurba
# Processing Record 24 of Set 10 | udachnyy
# Processing Record 25 of Set 10 | santa helena de goias
# Processing Record 26 of Set 10 | abu kamal
# Processing Record 27 of Set 10 | mokobeng
# Processing Record 28 of Set 10 | diamantino
# Processing Record 29 of Set 10 | balvi
# Processing Record 30 of Set 10 | scarborough
# Processing Record 31 of Set 10 | ulaangom
# Processing Record 32 of Set 10 | bengkulu
# Processing Record 33 of Set 10 | fort nelson
# Processing Record 34 of Set 10 | mabaruma
# Processing Record 35 of Set 10 | leshukonskoye
# Processing Record 36 of Set 10 | monrovia
# Processing Record 37 of Set 10 | thurso
# Processing Record 38 of Set 10 | majene
# Processing Record 39 of Set 10 | afgoye
# City not found. Skipping...
# Processing Record 40 of Set 10 | houma
# Processing Record 41 of Set 10 | te anau
# Processing Record 42 of Set 10 | suriapet
# Processing Record 43 of Set 10 | goshogawara
# Processing Record 44 of Set 10 | corum
# Processing Record 45 of Set 10 | saint-leu
# Processing Record 46 of Set 10 | candawaga
# City not found. Skipping...
# Processing Record 47 of Set 10 | fairbanks
# Processing Record 48 of Set 10 | peniche
# Processing Record 49 of Set 10 | cortez
# Processing Record 50 of Set 10 | clyde river
# Processing Record 1 of Set 11 | prince george
# Processing Record 2 of Set 11 | campbell river
# Processing Record 3 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 4 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 6 of Set 11 | cherskiy
# Processing Record 7 of Set 11 | vaitape
# Processing Record 8 of Set 11 | itoman
# Processing Record 9 of Set 11 | maldonado
# Processing Record 10 of Set 11 | ponta delgada
# Processing Record 11 of Set 11 | nybro
# Processing Record 12 of Set 11 | iracoubo
# Processing Record 13 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 11 | plettenberg bay
# Processing Record 15 of Set 11 | nanning
# Processing Record 16 of Set 11 | camacha
# Processing Record 17 of Set 11 | vangaindrano
# Processing Record 18 of Set 11 | prestea
# Processing Record 19 of Set 11 | havoysund
# Processing Record 20 of Set 11 | mehamn
# Processing Record 21 of Set 11 | daly city
# Processing Record 22 of Set 11 | nicoya
# Processing Record 23 of Set 11 | manaus
# Processing Record 24 of Set 11 | troitskoye
# Processing Record 25 of Set 11 | la romana
# Processing Record 26 of Set 11 | maceio
# Processing Record 27 of Set 11 | manokwari
# Processing Record 28 of Set 11 | port augusta
# Processing Record 29 of Set 11 | beloha
# Processing Record 30 of Set 11 | chiredzi
# Processing Record 31 of Set 11 | kribi
# Processing Record 32 of Set 11 | koslan
# Processing Record 33 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 34 of Set 11 | khilok
# Processing Record 35 of Set 11 | piranshahr
# Processing Record 36 of Set 11 | port-gentil
# Processing Record 37 of Set 11 | manado
# Processing Record 38 of Set 11 | tiarei
# Processing Record 39 of Set 11 | copiapo
# Processing Record 40 of Set 11 | cawayan
# Processing Record 41 of Set 11 | middlebury
# Processing Record 42 of Set 11 | subate
# Processing Record 43 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 44 of Set 11 | cedar city
# Processing Record 45 of Set 11 | waddan
# Processing Record 46 of Set 11 | limbazi
# Processing Record 47 of Set 11 | berdigestyakh
# Processing Record 48 of Set 11 | port macquarie
# Processing Record 49 of Set 11 | praia
# Processing Record 50 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 12 | maine-soroa
# Processing Record 2 of Set 12 | filadelfia
# Processing Record 3 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 12 | moron
# Processing Record 5 of Set 12 | korsakov
# Processing Record 6 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 12 | penzance
# Processing Record 8 of Set 12 | tsabong
# Processing Record 9 of Set 12 | ligayan
# Processing Record 10 of Set 12 | yanggu
# Processing Record 11 of Set 12 | ahipara
# Processing Record 12 of Set 12 | kandrian
# Processing Record 13 of Set 12 | dwarahat
# Processing Record 14 of Set 12 | tiznit
# Processing Record 15 of Set 12 | la ronge
# Processing Record 16 of Set 12 | sosnovo-ozerskoye
# Processing Record 17 of Set 12 | pauini
# Processing Record 18 of Set 12 | ayia marina
# Processing Record 19 of Set 12 | prado
# Processing Record 20 of Set 12 | san policarpo
# Processing Record 21 of Set 12 | helong
# Processing Record 22 of Set 12 | waingapu
# Processing Record 23 of Set 12 | simao
# Processing Record 24 of Set 12 | barrancas
# Processing Record 25 of Set 12 | voznesenye
# Processing Record 26 of Set 12 | kasungu
# Processing Record 27 of Set 12 | xichang
# Processing Record 28 of Set 12 | syracuse
# Processing Record 29 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 30 of Set 12 | gayeri
# Processing Record 31 of Set 12 | bandarbeyla
# Processing Record 32 of Set 12 | kavaratti
# Processing Record 33 of Set 12 | kochubey
# Processing Record 34 of Set 12 | inhambane
# Processing Record 35 of Set 12 | lelystad
# Processing Record 36 of Set 12 | baghmara
# Processing Record 37 of Set 12 | tignere
# Processing Record 38 of Set 12 | san carlos de bariloche
# Processing Record 39 of Set 12 | palu
# Processing Record 40 of Set 12 | west wendover
# Processing Record 41 of Set 12 | guasdualito
# Processing Record 42 of Set 12 | astghadzor
# Processing Record 43 of Set 12 | okhotsk
# Processing Record 44 of Set 12 | saurimo
# Processing Record 45 of Set 12 | sabzevar
# Processing Record 46 of Set 12 | silifke
# Processing Record 47 of Set 12 | constitucion
# Processing Record 48 of Set 12 | atar
# Processing Record 49 of Set 12 | puerto escondido
# Processing Record 50 of Set 12 | caxito
# Processing Record 1 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 2 of Set 13 | sabang
# Processing Record 3 of Set 13 | orsha
# Processing Record 4 of Set 13 | slobidka
# Processing Record 5 of Set 13 | tigil
# Processing Record 6 of Set 13 | owando
# Processing Record 7 of Set 13 | prescott
# Processing Record 8 of Set 13 | koungou
# Processing Record 9 of Set 13 | rio grande
# Processing Record 10 of Set 13 | marawi
# Processing Record 11 of Set 13 | jiancheng
# Processing Record 12 of Set 13 | kolyvan
# Processing Record 13 of Set 13 | kemin
# Processing Record 14 of Set 13 | portland
# Processing Record 15 of Set 13 | merauke
# Processing Record 16 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 13 | manggar
# Processing Record 18 of Set 13 | ucluelet
# Processing Record 19 of Set 13 | roald
# Processing Record 20 of Set 13 | lasa
# Processing Record 21 of Set 13 | wajima
# Processing Record 22 of Set 13 | moba
# Processing Record 23 of Set 13 | missoula
# Processing Record 24 of Set 13 | kidal
# Processing Record 25 of Set 13 | chara
# Processing Record 26 of Set 13 | erzin
# Processing Record 27 of Set 13 | arman
# Processing Record 28 of Set 13 | porbandar
# Processing Record 29 of Set 13 | panjab
# Processing Record 30 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 13 | kahama
# Processing Record 32 of Set 13 | luganville
# Processing Record 33 of Set 13 | shieli
# Processing Record 34 of Set 13 | oriximina
# Processing Record 35 of Set 13 | bara
# Processing Record 36 of Set 13 | kihei
# Processing Record 37 of Set 13 | alice springs
# Processing Record 38 of Set 13 | omsukchan
# Processing Record 39 of Set 13 | port blair
# Processing Record 40 of Set 13 | rumoi
# Processing Record 41 of Set 13 | manakara
# Processing Record 42 of Set 13 | irbeyskoye
# Processing Record 43 of Set 13 | oranjestad
# Processing Record 44 of Set 13 | cartagena
# Processing Record 45 of Set 13 | jardim
# Processing Record 46 of Set 13 | taltal
# Processing Record 47 of Set 13 | vila franca do campo
# Processing Record 48 of Set 13 | upington
# Processing Record 49 of Set 13 | meppen
# Processing Record 50 of Set 13 | qasigiannguit
# Processing Record 1 of Set 14 | ayagoz
# Processing Record 2 of Set 14 | moyale
# Processing Record 3 of Set 14 | impfondo
# Processing Record 4 of Set 14 | ipameri
# Processing Record 5 of Set 14 | rio gallegos
# Processing Record 6 of Set 14 | krasnoselkup
# Processing Record 7 of Set 14 | isiro
# Processing Record 8 of Set 14 | miyako
# Processing Record 9 of Set 14 | kleive
# Processing Record 10 of Set 14 | antofagasta
# Processing Record 11 of Set 14 | nkowakowa
# Processing Record 12 of Set 14 | yekimovichi
# Processing Record 13 of Set 14 | bac lieu
# Processing Record 14 of Set 14 | yorosso
# Processing Record 15 of Set 14 | peace river
# Processing Record 16 of Set 14 | rosario
# Processing Record 17 of Set 14 | kuloy
# Processing Record 18 of Set 14 | bossembele
# City not found. Skipping...
# Processing Record 19 of Set 14 | jacareacanga
# Processing Record 20 of Set 14 | trindade
# Processing Record 21 of Set 14 | ozernovskiy
# Processing Record 22 of Set 14 | camp verde
# Processing Record 23 of Set 14 | torres
# Processing Record 24 of Set 14 | santo antonio do sudoeste
# Processing Record 25 of Set 14 | katobu
# Processing Record 26 of Set 14 | kulhudhuffushi
# Processing Record 27 of Set 14 | betanzos
# Processing Record 28 of Set 14 | puerto pailas
# Processing Record 29 of Set 14 | ankang
# Processing Record 30 of Set 14 | batabano
# Processing Record 31 of Set 14 | port hardy
# Processing Record 32 of Set 14 | harper
# Processing Record 33 of Set 14 | sulangan
# Processing Record 34 of Set 14 | gwanda
# Processing Record 35 of Set 14 | verin
# Processing Record 36 of Set 14 | daxian
# City not found. Skipping...
# Processing Record 37 of Set 14 | nouadhibou
# Processing Record 38 of Set 14 | kirkuk
# Processing Record 39 of Set 14 | honefoss
# Processing Record 40 of Set 14 | coihaique
# Processing Record 41 of Set 14 | conde
# Processing Record 42 of Set 14 | tulum
# Processing Record 43 of Set 14 | solnechnyy
# Processing Record 44 of Set 14 | abay
# Processing Record 45 of Set 14 | shyroke
# Processing Record 46 of Set 14 | akyab
# Processing Record 47 of Set 14 | almeirim
# Processing Record 48 of Set 14 | honningsvag
# Processing Record 49 of Set 14 | matara
# Processing Record 50 of Set 14 | hays
# Processing Record 1 of Set 15 | angelholm
# City not found. Skipping...
# Processing Record 2 of Set 15 | egvekinot
# Processing Record 3 of Set 15 | suifenhe
# Processing Record 4 of Set 15 | aksu
# Processing Record 5 of Set 15 | salalah
# Processing Record 6 of Set 15 | qandala
# Processing Record 7 of Set 15 | sturgis
# Processing Record 8 of Set 15 | mweka
# Processing Record 9 of Set 15 | minot
# Processing Record 10 of Set 15 | jaipur
# Processing Record 11 of Set 15 | asau
# Processing Record 12 of Set 15 | mokhsogollokh
# Processing Record 13 of Set 15 | guajara-mirim
# City not found. Skipping...
# Processing Record 14 of Set 15 | caloundra
# Processing Record 15 of Set 15 | rong kwang
# Processing Record 16 of Set 15 | gainesville
# Processing Record 17 of Set 15 | rognan
# Processing Record 18 of Set 15 | guerrero negro
# Processing Record 19 of Set 15 | porto novo
# Processing Record 20 of Set 15 | corvallis
# Processing Record 21 of Set 15 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 22 of Set 15 | sonoita
# Processing Record 23 of Set 15 | goderich
# Processing Record 24 of Set 15 | bhopal
# Processing Record 25 of Set 15 | puerto colombia
# Processing Record 26 of Set 15 | paytug
# City not found. Skipping...
# Processing Record 27 of Set 15 | kazerun
# Processing Record 28 of Set 15 | zhicheng
# Processing Record 29 of Set 15 | chikhli
# Processing Record 30 of Set 15 | vila
# Processing Record 31 of Set 15 | hofn
# Processing Record 32 of Set 15 | redlands
# Processing Record 33 of Set 15 | shakawe
# Processing Record 34 of Set 15 | batticaloa
# Processing Record 35 of Set 15 | khasan
# Processing Record 36 of Set 15 | porto walter
# Processing Record 37 of Set 15 | eregli
# Processing Record 38 of Set 15 | chachapoyas
# Processing Record 39 of Set 15 | galanta
# Processing Record 40 of Set 15 | sedro-woolley
# Processing Record 41 of Set 15 | ulundi
# Processing Record 42 of Set 15 | ayolas
# Processing Record 43 of Set 15 | keetmanshoop
# Processing Record 44 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 15 | concarneau
# Processing Record 46 of Set 15 | poum
# Processing Record 47 of Set 15 | dwarka
# Processing Record 48 of Set 15 | maumere
# Processing Record 49 of Set 15 | thoen
# Processing Record 50 of Set 15 | honiara
# Processing Record 1 of Set 16 | ipixuna
# Processing Record 2 of Set 16 | barrhead
# Processing Record 3 of Set 16 | kissidougou
# Processing Record 4 of Set 16 | skjervoy
# Processing Record 5 of Set 16 | cockburn town
# Processing Record 6 of Set 16 | metro
# Processing Record 7 of Set 16 | saint anthony
# Processing Record 8 of Set 16 | svarstad
# Processing Record 9 of Set 16 | aginskoye
# Processing Record 10 of Set 16 | tibati
# Processing Record 11 of Set 16 | bugiri
# Processing Record 12 of Set 16 | vostok
# Processing Record 13 of Set 16 | mahibadhoo
# Processing Record 14 of Set 16 | campos belos
# Processing Record 15 of Set 16 | baghdad
# Processing Record 16 of Set 16 | manthani
# Processing Record 17 of Set 16 | coquimbo
# Processing Record 18 of Set 16 | ust-omchug
# Processing Record 19 of Set 16 | gamba
# Processing Record 20 of Set 16 | sampit
# Processing Record 21 of Set 16 | springbok
# Processing Record 22 of Set 16 | isabela
# Processing Record 23 of Set 16 | newport
# Processing Record 24 of Set 16 | vestmanna
# Processing Record 25 of Set 16 | robertsport
# Processing Record 26 of Set 16 | channel-port aux basques
# Processing Record 27 of Set 16 | cheuskiny
# City not found. Skipping...
# Processing Record 28 of Set 16 | hay river
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Fuling  29.7022  107.3919     84.70        72         100        2.71
# 1  Upernavik  72.7868  -56.1549     42.89        78         100        6.76
# 2      Bluff -46.6000  168.3333     43.68        61           3       17.18
# 3    Ushuaia -54.8000  -68.3000     38.86        56          75        6.91
# 4    Fortuna  40.5982 -124.1573     75.92        64          20       10.36
#
#   Country Current Description
# 0      CN     overcast clouds
# 1      GL     overcast clouds
# 2      NZ           clear sky
# 3      AR       broken clouds
# 4      US          few clouds

# %%
city_data_df.to_csv("Weather_Database/WeatherPy_Database.csv")
